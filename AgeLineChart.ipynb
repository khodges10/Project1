# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
nba_csv = "Data/NBAKeyStats.csv"
nba_key = pd.read_csv(nba_csv)

# %%
fig, ax = plt.subplots(figsize=(15,7))
nba_key = nba_key.groupby(["Year", "Status"])
nba_average = nba_key["Age"].mean()
nba_average.unstack().plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
plt.title("Age Representation by Team Status")
plt.xlabel("Year")
plt.ylabel("Age")
# Out:
# Text(308.94444444444446, 0.5, 'Age')

# %%
plt.savefig("AgeLineChart.png", bbox_inches="tight")
plt.show()

# %%
nba_average
# Only 3 times Champion was lower average age than average PQ. Never lower than NP. CC and NBAC very similar.
# 1) NBAC = 28.796552, 2) CC = 28.265517, 3) PQ = 27.620936, 4) NP = 26.127968. Average's of all years together.
# So experience is a more important indicator of success than youth.
# Out:
# Year  Status
# 1990  CC        26.700000
#       NBAC      29.500000
#       NP        26.200000
#       PQ        27.642857
# 1991  CC        28.400000
#       NBAC      26.900000
#       NP        26.309091
#       PQ        27.814286
# 1992  CC        28.100000
#       NBAC      27.600000
#       NP        26.936364
#       PQ        27.271429
# 1993  CC        28.200000
#       NBAC      28.100000
#       NP        26.181818
#       PQ        27.671429
# 1994  CC        28.900000
#       NBAC      28.100000
#       NP        26.700000
#       PQ        27.392857
# 1995  CC        26.600000
#       NBAC      28.500000
#       NP        25.800000
#       PQ        28.300000
# 1996  CC        29.600000
#       NBAC      29.900000
#       NP        26.446154
#       PQ        28.207143
# 1997  CC        29.600000
#       NBAC      30.700000
#                   ...
# 2011  NP        25.921429
#       PQ        26.785714
# 2012  CC        25.100000
#       NBAC      28.300000
# ...
