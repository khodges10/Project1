# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
nba_seasondata = "Data/Seasons_Stats.csv"
nba_player = "Data/player_data.csv"
winning_teams = "Data/winning_teams.csv"
team_records = "Data/Team_Records.csv"
nba_csv = "Data/NBAKeyStats.csv"

nba_key = pd.read_csv(nba_csv)
nba_data1 = pd.read_csv(nba_seasondata)
nba_data2 = pd.read_csv(nba_player)
winning_df = pd.read_csv(winning_teams)
team_stats =pd.read_csv(team_records)

# %%
team_stats.head()
# Out:
#     Season   Lg             Team   W   L   W/L%  Finish   SRS  Pace  Rel_Pace  \
# 0  2017-18  NBA   Boston Celtics  29  10  0.744       1  4.38  95.4      -1.7
# 1  2016-17  NBA  Boston Celtics*  53  29  0.646       1  2.25  96.8       0.4
# 2  2015-16  NBA  Boston Celtics*  48  34  0.585       2  2.84  98.5       2.7
# 3  2014-15  NBA  Boston Celtics*  40  42  0.488       2 -0.40  95.8       1.9
# 4  2013-14  NBA   Boston Celtics  25  57  0.305       4 -4.97  93.3      -0.6
#
#     ORtg  Rel_ORtg   DRtg  Rel_DRtg                Playoffs  \
# 0  108.0       0.2  102.8      -5.0                     NaN
# 1  111.2       2.4  108.4      -0.4    Lost E. Conf. Finals
# 2  106.8       0.4  103.6      -2.8  Lost E. Conf. 1st Rnd.
# 3  104.7      -0.9  104.5      -1.1  Lost E. Conf. 1st Rnd.
# 4  102.9      -3.8  107.7       1.0                     NaN
#
#               Coaches            Top WS
# 0  B. Stevens (29-10)   K. Irving (5.7)
# 1  B. Stevens (53-29)  I. Thomas (12.5)
# ...

# %%
#Merge CSVs
nba_data2 = nba_data2.rename(columns = {"name":"Player"})
nba_dataset = pd.merge(nba_data1, nba_data2, how='left',on='Player')
#nba_dataset.head()

#listing columns needed
nba_champion = nba_dataset[["Year", "Player", "Tm", "Age", "Pos", "college"]]
nba_champion.head()
# Out:
#      Year           Player   Tm   Age  Pos                          college
# 0  1950.0  Curly Armstrong  FTW  31.0  G-F               Indiana University
# 1  1950.0     Cliff Barker  INO  29.0   SG           University of Kentucky
# 2  1950.0    Leo Barnhorst  CHS  25.0   SF         University of Notre Dame
# 3  1950.0       Ed Bartels  TOT  24.0    F  North Carolina State University
# 4  1950.0       Ed Bartels  DNN  24.0    F  North Carolina State University

# %%
nba_champ_age = nba_champion["Age"].mean
nba_champ_age
# Out:
# <bound method Series.mean of 0        31.0
# 1        29.0
# 2        25.0
# 3        24.0
# 4        24.0
# 5        24.0
# 6        22.0
# 7        23.0
# 8        28.0
# 9        28.0
# 10       28.0
# 11       25.0
# 12       22.0
# 13       22.0
# 14       24.0
# 15       27.0
# 16       21.0
# 17       24.0
# 18       22.0
# 19       26.0
# 20       29.0
# 21       26.0
# 22       20.0
# 23       24.0
# 24       23.0
# 25       26.0
# 26       22.0
# 27       30.0
# 28       32.0
# 29       25.0
#          ...
# 25267    32.0
# 25268    32.0
# 25269    25.0
# 25270    25.0
# 25271    25.0
# 25272    30.0
# 25273    30.0
# 25274    30.0
# 25275    30.0
# 25276    30.0
# 25277    30.0
# 25278    22.0
# 25279    22.0
# 25280    22.0
# 25281    24.0
# 25282    20.0
# 25283    26.0
# 25284    21.0
# 25285    37.0
# 25286    29.0
# 25287    24.0
# 25288    21.0
# 25289    24.0
# 25290    31.0
# 25291    28.0
# 25292    24.0
# 25293    27.0
# 25294    20.0
# 25295    22.0
# ...

# %%
#renaming columns
nba_key = nba_key.rename(columns = {"TOV%.1":"TOV%", "eFG%.1":"eFG%", "FT/FGA.1":"FT/FGA"})

# %%
nba_key.head()
#create new column for W
# Out:
#    Year  Rank Status                     Team   Age     W     L    PW  PL  \
# 0  1990   1.0     PQ            Phoenix Suns*  26.7  54.0  28.0  58.0  24
# 1  1990   2.0     PQ      Los Angeles Lakers*  28.9  63.0  19.0  58.0  24
# 2  1990   3.0     CC  Portland Trail Blazers*  26.7  59.0  23.0  57.0  25
# 3  1990   4.0   NBAC         Detroit Pistons*  29.5  59.0  23.0  57.0  25
# 4  1990   5.0     PQ               Utah Jazz*  27.6  55.0  27.0  54.0  28
#
#     MOV  ...   3PAr    TS%   eFG%  TOV%  ORB%  FT/FGA   eFG%  TOV%  DRB%  \
# 0  7.10  ...  0.076  0.565  0.509  13.3  31.1   0.302  0.478  12.8  68.8
# 1  6.78  ...  0.120  0.562  0.512  13.2  32.8   0.271  0.479  12.8  68.5
# 2  6.32  ...  0.075  0.535  0.486  13.4  36.5   0.269  0.479  15.2  70.8
# 3  6.09  ...  0.078  0.537  0.490  13.4  34.2   0.245  0.461  13.7  70.3
# 4  4.79  ...  0.096  0.570  0.522  15.5  30.1   0.284  0.468  13.4  69.5
#
#    FT/FGA
# 0   0.209
# 1   0.219
# 2   0.265
# 3   0.262
# 4   0.268
#
# ...

# %% [markdown]
# # ploting mean age of champs vs nonchamps
#
# nba_key.plot(kind="line", x="Status", y="Age", grid=True, figsize=(9,8),
# title="Champs age vs nonchamps")
# plt.show()

# %%
Losing_teams = []

# loss =nba_key["Status"] ==('PQ' and 'CC' and 'NP')
# nba_key_loss = nba_key[loss]
# nba_key_loss.count()

# if Status == ('PQ' or 'CC' or 'NP')
# Lossing_teams.append()

# for i in ["Status"]:
#     Losing_teams.append(i.split('PQ')[0])

Losing_teams = [nba_key[:nba_key.index('Status')] if 'NP' in 'Status'
                else 'CC' for Status in Losing_teams]
Losing_teams.append
Losing_teams
# Out:
# []

# %%
# plot data
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
nba_key.groupby(['Status'])['Age'].plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="1499.9999403953575">
# Status
# CC      AxesSubplot(0.125,0.11;0.775x0.77)
# NBAC    AxesSubplot(0.125,0.11;0.775x0.77)
# NP      AxesSubplot(0.125,0.11;0.775x0.77)
# PQ      AxesSubplot(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object
