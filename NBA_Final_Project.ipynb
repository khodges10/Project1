# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#importing csv and reading
nba_seasondata = "Data/Seasons_Stats.csv"
nba_player = "Data/player_data.csv"

nba_data1 = pd.read_csv(nba_seasondata)
nba_data2 = pd.read_csv(nba_player)
nba_data2.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
#renaming columns
nba_data2 = nba_data2.rename(columns = {"name":"Player"})

# %%
#mergeing 1 and 2
nba_dataset = pd.merge(nba_data1, nba_data2, how='left',on='Player')
nba_dataset.head()
nba_dataset.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year_start', 'year_end',
#        'position', 'height', 'weight', 'birth_date', 'college'],
#       dtype='object')

# %%
# making a DF with targeted info
nba_champion = nba_dataset[["Year", "Player", "Tm", "Age", "Pos", "college", "height"]]
nba_champion.head()
# Out:
#      Year           Player   Tm   Age  Pos                          college  \
# 0  1950.0  Curly Armstrong  FTW  31.0  G-F               Indiana University
# 1  1950.0     Cliff Barker  INO  29.0   SG           University of Kentucky
# 2  1950.0    Leo Barnhorst  CHS  25.0   SF         University of Notre Dame
# 3  1950.0       Ed Bartels  TOT  24.0    F  North Carolina State University
# 4  1950.0       Ed Bartels  DNN  24.0    F  North Carolina State University
#
#   height
# 0   5-11
# 1    6-2
# 2    6-4
# 3    6-5
# 4    6-5

# %%
# winning teams by year 1990-2018
nba_1990champion = nba_champion.loc[nba_champion["Year"] == 1990.0]
nba_1990champion = nba_1990champion.loc[nba_1990champion["Tm"] == "DET"]

# %%
nba_1991champion = nba_champion.loc[nba_champion["Year"] == 1991.0]
nba_1991champion = nba_1991champion.loc[nba_1991champion["Tm"] == "CHI"]

#starting a champing team DF
combined1 = pd.merge(nba_1990champion, nba_1991champion, how='outer')

# %%
nba_1992champion = nba_champion.loc[nba_champion["Year"] == 1992.0]
nba_1992champion = nba_1992champion.loc[nba_1992champion["Tm"] == "CHI"]

combined2 = pd.merge(combined1, nba_1992champion, how='outer')

# %%
nba_1993champion = nba_champion.loc[nba_champion["Year"] == 1993.0]
nba_1993champion = nba_1993champion.loc[nba_1993champion["Tm"] == "CHI"]

combined3 = pd.merge(combined2, nba_1993champion, how='outer')

# %%
nba_1994champion = nba_champion.loc[nba_champion["Year"] == 1994.0]
nba_1994champion = nba_1994champion.loc[nba_1994champion["Tm"] == "HOU"]


combined4 = pd.merge(combined3, nba_1994champion, how='outer')

# %%
nba_1995champion = nba_champion.loc[nba_champion["Year"] == 1995.0]
nba_1995champion = nba_1995champion.loc[nba_1995champion["Tm"] == "HOU"]

combined5 = pd.merge(combined4, nba_1995champion, how='outer')

# %%
nba_1996champion = nba_champion.loc[nba_champion["Year"] == 1996.0]
nba_1996champion = nba_1996champion.loc[nba_1996champion["Tm"] == "CHI"]

combined6 = pd.merge(combined5, nba_1996champion, how='outer')

# %%
nba_1997champion = nba_champion.loc[nba_champion["Year"] == 1997.0]
nba_1997champion = nba_1997champion.loc[nba_1997champion["Tm"] == "CHI"]

combined7 = pd.merge(combined6, nba_1997champion, how='outer')

# %%
nba_1998champion = nba_champion.loc[nba_champion["Year"] == 1998.0]
nba_1998champion = nba_1998champion.loc[nba_1998champion["Tm"] == "CHI"]

combined8 = pd.merge(combined7, nba_1998champion, how='outer')

# %%
nba_1999champion = nba_champion.loc[nba_champion["Year"] == 1999.0]
nba_1999champion = nba_1999champion.loc[nba_1999champion["Tm"] == "SAS"]

combined9 = pd.merge(combined8, nba_1999champion, how='outer')

# %%
nba_2000champion = nba_champion.loc[nba_champion["Year"] == 2000.0]
nba_2000champion = nba_2000champion.loc[nba_2000champion["Tm"] == "LAL"]

combined10 = pd.merge(combined9, nba_2000champion, how='outer')

# %%
nba_2001champion = nba_champion.loc[nba_champion["Year"] == 2001.0]
nba_2001champion = nba_2001champion.loc[nba_2001champion["Tm"] == "LAL"]

combined11 = pd.merge(combined10, nba_2001champion, how='outer')

# %%
nba_2002champion = nba_champion.loc[nba_champion["Year"] == 2002.0]
nba_2002champion = nba_2002champion.loc[nba_2002champion["Tm"] == "LAL"]

combined12 = pd.merge(combined11, nba_2002champion, how='outer')

# %%
nba_2003champion = nba_champion.loc[nba_champion["Year"] == 2003.0]
nba_2003champion = nba_2003champion.loc[nba_2003champion["Tm"] == "SAS"]

combined13 = pd.merge(combined12, nba_2003champion, how='outer')

# %%
nba_2004champion = nba_champion.loc[nba_champion["Year"] == 2004.0]
nba_2004champion = nba_2004champion.loc[nba_2004champion["Tm"] == "DET"]

combined14 = pd.merge(combined13, nba_2004champion, how='outer')

# %%
nba_2005champion = nba_champion.loc[nba_champion["Year"] == 2005.0]
nba_2005champion = nba_2005champion.loc[nba_2005champion["Tm"] == "SAS"]

combined15 = pd.merge(combined14, nba_2005champion, how='outer')

# %%
nba_2006champion = nba_champion.loc[nba_champion["Year"] == 2006.0]
nba_2006champion = nba_2006champion.loc[nba_2006champion["Tm"] == "MIA"]

combined16 = pd.merge(combined15, nba_2006champion, how='outer')

# %%
nba_2007champion = nba_champion.loc[nba_champion["Year"] == 2007.0]
nba_2007champion = nba_2007champion.loc[nba_2007champion["Tm"] == "SAS"]

combined17 = pd.merge(combined16, nba_2007champion, how='outer')

# %%
nba_2008champion = nba_champion.loc[nba_champion["Year"] == 2008.0]
nba_2008champion = nba_2008champion.loc[nba_2008champion["Tm"] == "BOS"]

combined18 = pd.merge(combined17, nba_2008champion, how='outer')

# %%
nba_2009champion = nba_champion.loc[nba_champion["Year"] == 2009.0]
nba_2009champion = nba_2009champion.loc[nba_2009champion["Tm"] == "LAL"]

combined19 = pd.merge(combined18, nba_2009champion, how='outer')

# %%
nba_2010champion = nba_champion.loc[nba_champion["Year"] == 2010.0]
nba_2010champion = nba_2010champion.loc[nba_2010champion["Tm"] == "LAL"]

combined20 = pd.merge(combined19, nba_2010champion, how='outer')

# %%
nba_2011champion = nba_champion.loc[nba_champion["Year"] == 2011.0]
nba_2011champion = nba_2011champion.loc[nba_2011champion["Tm"] == "DAL"]

combined21 = pd.merge(combined20, nba_2011champion, how='outer')

# %%
nba_2012champion = nba_champion.loc[nba_champion["Year"] == 2012.0]
nba_2012champion = nba_2012champion.loc[nba_2012champion["Tm"] == "MIA"]

combined22 = pd.merge(combined21, nba_2012champion, how='outer')

# %%
nba_2013champion = nba_champion.loc[nba_champion["Year"] == 2013.0]
nba_2013champion = nba_2013champion.loc[nba_2013champion["Tm"] == "MIA"]

combined23 = pd.merge(combined22, nba_2013champion, how='outer')

# %%
nba_2014champion = nba_champion.loc[nba_champion["Year"] == 2014.0]
nba_2014champion = nba_2014champion.loc[nba_2014champion["Tm"] == "SAS"]

combined24 = pd.merge(combined23, nba_2014champion, how='outer')

# %%
nba_2015champion = nba_champion.loc[nba_champion["Year"] == 2015.0]
nba_2015champion = nba_2015champion.loc[nba_2015champion["Tm"] == "GSW"]

combined25 = pd.merge(combined24, nba_2015champion, how='outer')

# %%
nba_2016champion = nba_champion.loc[nba_champion["Year"] == 2016.0]
nba_2016champion = nba_2016champion.loc[nba_2016champion["Tm"] == "CLE"]

combined26 = pd.merge(combined25, nba_2016champion, how='outer')

# %%
nba_2017champion = nba_champion.loc[nba_champion["Year"] == 2017.0]
nba_2017champion = nba_2017champion.loc[nba_2017champion["Tm"] == "GSW"]

combined27 = pd.merge(combined26, nba_2017champion, how='outer')

# %%
nba_2018champion = nba_champion.loc[nba_champion["Year"] == 2018.0]
nba_2018champion = nba_2018champion.loc[nba_2018champion["Tm"] == "GSW"]

combined28 = pd.merge(combined27, nba_2018champion, how='outer')
combined28.head()
# Out:
#      Year           Player   Tm   Age Pos  \
# 0  1990.0     Mark Aguirre  DET  30.0  SF
# 1  1990.0  William Bedford  DET  26.0   C
# 2  1990.0      Joe Dumars*  DET  26.0  SG
# 3  1990.0    James Edwards  DET  34.0   C
# 4  1990.0   Dave Greenwood  DET  32.0  PF
#
#                                  college height
# 0                      DePaul University    6-6
# 1                  University of Memphis    7-0
# 2                                    NaN    NaN
# 3               University of Washington    7-0
# 4  University of California, Los Angeles    6-9

# %%
combined28.dtypes
# Out:
# Year       float64
# Player      object
# Tm          object
# Age        float64
# Pos         object
# college     object
# height      object
# dtype: object

# %%
# sorting players by college
Playercount = combined28.groupby("college")
college = Playercount.nunique()["Player"]
college.sort_values(ascending=False)
# Out:
# college
# University of California, Los Angeles      11
# University of Arizona                       9
# University of Florida                       9
# University of North Carolina                9
# University of Kansas                        8
# University of Kentucky                      7
# University of Texas at Austin               6
# University of Connecticut                   5
# Duke University                             5
# Michigan State University                   5
# Georgia Institute of Technology             5
# University of Arkansas                      4
# University of California                    4
# University of Michigan                      4
# University of Nevada, Las Vegas             4
# University of Alabama                       3
# Gonzaga University                          3
# Providence College                          3
# Oregon State University                     3
# University of Iowa                          3
# ...

# %%
#graphing champ players by college
cities = ["UCLA", "Arizona", "UF", "UNC", "Kansas", "Kentucky", "Texas", "UConn", "Duke", "MSU", "GT"]
college_count = [11.0, 9.0, 9.0, 9.0, 8.0, 7.0, 6.0, 5.0, 5.0, 5.0, 5.0]
x_axis = np.arange(len(college_count))
plt.bar(x_axis, college_count, color=['royalblue', 'navy', 'orange', 'deepskyblue', 'red', 'mediumblue', 'darkorange',
                                      'grey', 'blue', 'green', 'gold'], align="center")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, cities)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(college_count)+0.4)
#labels
plt.title("Championship Players by College")
plt.xlabel("College")
plt.ylabel("Championships")
plt.savefig("CollegeChampionships.png", bbox_inches="tight")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# importing hand made csv
nba_csv = "Data/NBAKeyStats.csv"
nba_key = pd.read_csv(nba_csv)
nba_key.columns
# Out:
# Index(['Year', 'Rank', 'Status', 'Team', 'Age', 'W', 'L', 'PW', 'PL', 'MOV',
#        'SOS', 'SRS', 'ORtg', 'DRtg', 'NRtg', 'Pace', 'FTr', '3PAr', 'TS%',
#        'eFG%', 'TOV%', 'ORB%', 'FT/FGA', 'eFG%.1', 'TOV%.1', 'DRB%',
#        'FT/FGA.1'],
#       dtype='object')

# %%
nba_key.head()
# Out:
#    Year  Rank Status                     Team   Age     W     L    PW  PL  \
# 0  1990   1.0     PQ            Phoenix Suns*  26.7  54.0  28.0  58.0  24
# 1  1990   2.0     PQ      Los Angeles Lakers*  28.9  63.0  19.0  58.0  24
# 2  1990   3.0     CC  Portland Trail Blazers*  26.7  59.0  23.0  57.0  25
# 3  1990   4.0   NBAC         Detroit Pistons*  29.5  59.0  23.0  57.0  25
# 4  1990   5.0     PQ               Utah Jazz*  27.6  55.0  27.0  54.0  28
#
#     MOV  ...   3PAr    TS%   eFG%  TOV%  ORB%  FT/FGA  eFG%.1  TOV%.1  DRB%  \
# 0  7.10  ...  0.076  0.565  0.509  13.3  31.1   0.302   0.478    12.8  68.8
# 1  6.78  ...  0.120  0.562  0.512  13.2  32.8   0.271   0.479    12.8  68.5
# 2  6.32  ...  0.075  0.535  0.486  13.4  36.5   0.269   0.479    15.2  70.8
# 3  6.09  ...  0.078  0.537  0.490  13.4  34.2   0.245   0.461    13.7  70.3
# 4  4.79  ...  0.096  0.570  0.522  15.5  30.1   0.284   0.468    13.4  69.5
#
#    FT/FGA.1
# 0     0.209
# 1     0.219
# 2     0.265
# ...

# %%
# index by status
nba_defense = nba_key.groupby("Status")
nba_defense.mean().round(3)
# Out:
#             Year    Rank     Age       W       L      PW      PL    MOV  \
# Status
# CC      2004.000   4.862  28.266  55.517  24.828  54.931  25.414  5.615
# NBAC    2004.000   3.034  28.797  59.345  21.000  58.690  21.655  7.211
# NP      2004.641  22.528  26.128  28.865  51.446  29.540  50.781 -4.042
# PQ      2004.000   9.670  27.621  48.244  32.096  47.924  32.416  2.857
#
#           SOS    SRS  ...   3PAr    TS%   eFG%    TOV%    ORB%  FT/FGA  \
# Status                ...
# CC     -0.309  5.305  ...  0.214  0.553  0.509  13.903  28.290   0.249
# NBAC   -0.234  6.977  ...  0.210  0.552  0.512  13.434  28.803   0.225
# NP      0.181 -3.861  ...  0.193  0.523  0.480  14.073  28.094   0.223
# PQ     -0.131  2.727  ...  0.203  0.541  0.498  13.599  28.292   0.234
#
#         eFG%.1  TOV%.1    DRB%  FT/FGA.1
# Status
# CC       0.478  13.931  72.638     0.221
# NBAC     0.472  14.017  72.603     0.214
# NP       0.501  13.654  71.186     0.236
# ...

# %%
# Net ranking bar graph
nba_keydoe = nba_key.groupby(["Status"])
nba_barsgraph = nba_keydoe.mean()["Rank"]

plt.close('all')
nba_barsgraph.plot(kind="bar", x="Status", y="League Ranking", grid=False, figsize=(8,8), 
                   title="Net +/- Ranking", color=['black', 'green', 'blue', 'cyan'])

plt.savefig("NetRanking.png", bbox_inches="tight")
# Out:
# <img src="data:image/png;base64,..." width="799.9999682108573">

# %%
plt.close('all')
#Age line graph
fig, ax = plt.subplots(figsize=(15,7))
nba_key_gb = nba_key.groupby(["Year", "Status"])
nba_average = nba_key_gb["Age"].mean()
nba_average.unstack().plot(ax=ax)

#labels

plt.title("Age Representation by Team Status")
plt.xlabel("Year")
plt.ylabel("Age")
plt.savefig("AgeLineChart.png", bbox_inches="tight")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1499.9999403953575">

# %%
nba_average
# Out:
# Year  Status
# 1990  CC        26.700000
#       NBAC      29.500000
#       NP        26.200000
#       PQ        27.642857
# 1991  CC        28.400000
#       NBAC      26.900000
#       NP        26.309091
#       PQ        27.814286
# 1992  CC        28.100000
#       NBAC      27.600000
#       NP        26.936364
#       PQ        27.271429
# 1993  CC        28.200000
#       NBAC      28.100000
#       NP        26.181818
#       PQ        27.671429
# 1994  CC        28.900000
#       NBAC      28.100000
#       NP        26.700000
#       PQ        27.392857
# 1995  CC        26.600000
#       NBAC      28.500000
#       NP        25.800000
#       PQ        28.300000
# 1996  CC        29.600000
#       NBAC      29.900000
#       NP        26.446154
#       PQ        28.207143
# 1997  CC        29.600000
#       NBAC      30.700000
#                   ...
# 2011  NP        25.921429
#       PQ        26.785714
# 2012  CC        25.100000
#       NBAC      28.300000
# ...

# %%
nba_key.head()
# Out:
#    Year  Rank Status                     Team   Age     W     L    PW  PL  \
# 0  1990   1.0     PQ            Phoenix Suns*  26.7  54.0  28.0  58.0  24
# 1  1990   2.0     PQ      Los Angeles Lakers*  28.9  63.0  19.0  58.0  24
# 2  1990   3.0     CC  Portland Trail Blazers*  26.7  59.0  23.0  57.0  25
# 3  1990   4.0   NBAC         Detroit Pistons*  29.5  59.0  23.0  57.0  25
# 4  1990   5.0     PQ               Utah Jazz*  27.6  55.0  27.0  54.0  28
#
#     MOV  ...   3PAr    TS%   eFG%  TOV%  ORB%  FT/FGA  eFG%.1  TOV%.1  DRB%  \
# 0  7.10  ...  0.076  0.565  0.509  13.3  31.1   0.302   0.478    12.8  68.8
# 1  6.78  ...  0.120  0.562  0.512  13.2  32.8   0.271   0.479    12.8  68.5
# 2  6.32  ...  0.075  0.535  0.486  13.4  36.5   0.269   0.479    15.2  70.8
# 3  6.09  ...  0.078  0.537  0.490  13.4  34.2   0.245   0.461    13.7  70.3
# 4  4.79  ...  0.096  0.570  0.522  15.5  30.1   0.284   0.468    13.4  69.5
#
#    FT/FGA.1
# 0     0.209
# 1     0.219
# 2     0.265
# ...

# %%
# formula for Power ranking
nba_key["PR"] = ((nba_key["SRS"] + nba_key["MOV"]) + (nba_key["ORtg"] - 
                        nba_key["DRtg"]*1.25)) * (nba_key["eFG%"] * nba_key["TS%"]) + 10

# %%
#setting index to PR
nba_key = nba_key.sort_values("PR", ascending=False)
nba_key = nba_key.reset_index(drop=True)
nba_key.round(2)
# 10 of top 16 teams were champions
# Out:
#      Year  Rank Status                     Team   Age     W     L    PW  PL  \
# 0    1996   1.0   NBAC           Chicago Bulls*  29.9  72.0  10.0  70.0  12
# 1    2017   1.0   NBAC   Golden State Warriors*  28.2  67.0  15.0  67.0  15
# 2    2016   2.0     PQ       San Antonio Spurs*  30.3  67.0  15.0  67.0  15
# 3    1997   1.0   NBAC           Chicago Bulls*  30.7  69.0  13.0  68.0  14
# 4    2016   1.0     CC   Golden State Warriors*  27.4  73.0   9.0  65.0  17
# 5    2008   1.0   NBAC          Boston Celtics*  27.9  66.0  16.0  67.0  15
# 6    1992   1.0   NBAC           Chicago Bulls*  27.6  67.0  15.0  66.0  16
# 7    2015   1.0   NBAC   Golden State Warriors*  26.6  67.0  15.0  65.0  17
# 8    2013   1.0     PQ   Oklahoma City Thunder*  26.0  60.0  22.0  64.0  18
# 9    2009   1.0     PQ     Cleveland Cavaliers*  26.6  66.0  16.0  65.0  17
# 10   1994   1.0     PQ     Seattle SuperSonics*  28.1  63.0  19.0  64.0  18
# ...

# %%
nba_keydoe = nba_key.groupby(["Status"])
nba_barsgraph = nba_keydoe.mean()["PR"]

# %%
plt.close('all')
#plot bar for Power Rank
nba_barsgraph.plot(kind="bar", x="Status", y="Power Ranking", grid=False, figsize=(8,8), 
                   title="Average Power Ranking by Status", color=['black', 'green', 'blue', 'cyan'])
#save fig
plt.savefig("PRanking.png", bbox_inches="tight")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999682108573">

# %%
# making scatter plot for stranth of record and effective field goal %
sns.pairplot(x_vars=["SRS"], y_vars=["eFG%"], data=nba_key, hue="Status", height=5)
plt.title("SRS & eFG%")
plt.savefig("SRSvsEFGScatter.png", bbox_inches="tight")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="588.333309955068">

# %%
# nba_1950noncollege 
nba_1990noncollege = nba_1990champion.loc[nba_champion["Year"] == 1990.0]
nba_1990noncollege = nba_1990champion.loc[nba_1990champion["Tm"] != "DET"]
nba_1990noncollege = nba_1990champion["height"].mean 
nba_1990noncollege
# Out:
# <bound method Series.mean of 9809      6-6
# 9828      7-0
# 9909      NaN
# 9916      7-0
# 9953      6-9
# 9969     6-10
# 9975      6-2
# 9976      6-5
# 10007     6-2
# 10024    5-11
# 10032    6-11
# 10046     6-6
# 10155     NaN
# 10163    6-11
# 10211     NaN
# Name: height, dtype: object>

# %%
nba_1991noncollege = nba_1991champion.loc[nba_champion["Year"] == 1991.0]
nba_1991noncollege = nba_1991champion.loc[nba_1991champion["Tm"] != "CHI"]
nba_1991noncollege = nba_1991champion["height"].mean                                      
nba_1991noncollege
# Out:
# <bound method Series.mean of 10304     6-2
# 10352     7-1
# 10446    6-10
# 10473     6-2
# 10477     6-5
# 10502     NaN
# 10510    6-11
# 10529     6-8
# 10590     6-2
# 10593     7-0
# 10605     NaN
# 10727    6-10
# Name: height, dtype: object>

# %%
nba_1992noncollege = nba_1992champion.loc[nba_champion["Year"] == 1992.0]
nba_1992noncollege = nba_1992champion.loc[nba_1992champion["Tm"] != "CHI"]
nba_1992noncollege = nba_1992champion["height"].mean                                      
nba_1992noncollege
# Out:
# <bound method Series.mean of 10766     6-2
# 10827     7-1
# 10916    6-10
# 10926     6-6
# 10947     6-2
# 10950     6-5
# 10975     NaN
# 10983    6-11
# 11001     6-8
# 11054     7-5
# 11066     6-2
# 11069     7-0
# 11081     NaN
# 11093     6-8
# 11152     6-2
# 11208    6-10
# Name: height, dtype: object>

# %%
nba_1993noncollege = nba_1993champion.fillna(0)
nba_1993noncollege = nba_1993champion.loc[nba_champion["Year"] == 1993.0]
nba_1993noncollege = nba_1993champion.loc[nba_1993champion["Tm"] != "CHI"]
nba_1993noncollege = nba_1993champion["height"].mean                                      
nba_1993noncollege
# Out:
# <bound method Series.mean of 11240     6-2
# 11265     6-7
# 11293     7-1
# 11312     6-8
# 11347     NaN
# 11373    6-10
# 11426     NaN
# 11440    6-11
# 11481     6-7
# 11504     6-7
# 11524     6-2
# 11528     7-0
# 11538     NaN
# 11631     6-5
# 11638     6-4
# 11654     6-2
# 11667    6-10
# Name: height, dtype: object>

# %%
nba_1994noncollege = nba_1994champion.loc[nba_champion["Year"] == 1994.0]
nba_1994noncollege = nba_1994champion.loc[nba_1994champion["Tm"] != "HOU"]
nba_1994noncollege = nba_1994champion["height"].mean                                      
nba_1994noncollege
# Out:
# <bound method Series.mean of 11739    5-11
# 11748    6-10
# 11760     6-3
# 11788     6-9
# 11818     6-5
# 11879     6-9
# 11887     6-9
# 11903     6-7
# 11982     6-4
# 12020     NaN
# 12040    6-10
# 12060     7-0
# 12066     6-3
# 12096     6-3
# 12119     6-9
# Name: height, dtype: object>

# %%
nba_1995noncollege = nba_1995champion.loc[nba_champion["Year"] == 1995.50]
nba_1995noncollege = nba_1995champion.loc[nba_1995champion["Tm"] != "HOU"]
nba_1995noncollege = nba_1995champion["height"].mean                                      
nba_1995noncollege
# Out:
# <bound method Series.mean of 12222     6-7
# 12224    5-11
# 12226     6-7
# 12238     6-8
# 12243     6-3
# 12249    6-10
# 12283     NaN
# 12302     6-5
# 12358     6-9
# 12365     6-9
# 12385     6-9
# 12386     6-8
# 12387     6-3
# 12443     6-4
# 12471     6-7
# 12480     NaN
# 12560     6-3
# 12582     7-0
# 12587     6-9
# Name: height, dtype: object>

# %%
nba_1996noncollege = nba_1996champion.loc[nba_champion["Year"] == 1996.0]
nba_1996noncollege = nba_1996champion.loc[nba_1996champion["Tm"] != "CHI"]
nba_1996noncollege = nba_1996champion["height"].mean                                      
nba_1996noncollege
# Out:
# <bound method Series.mean of 12700     6-2
# 12702     6-6
# 12707     6-8
# 12775     7-0
# 12831    6-10
# 12846     6-6
# 12887     NaN
# 12892     6-3
# 12902    6-10
# 12922     7-2
# 13024     NaN
# 13062     NaN
# 13078    6-11
# 13089     6-9
# 13164     7-0
# Name: height, dtype: object>

# %%
nba_1997noncollege = nba_1997champion.loc[nba_champion["Year"] == 1997.0]
nba_1997noncollege = nba_1997champion.loc[nba_1997champion["Tm"] != "CHI"]
nba_1997noncollege = nba_1997champion["height"].mean                                      
nba_1997noncollege
# Out:
# <bound method Series.mean of 13272     6-2
# 13275     6-6
# 13282     6-8
# 13340     6-9
# 13427     6-6
# 13477     NaN
# 13484     6-3
# 13501    6-10
# 13518     7-2
# 13613     NaN
# 13627     NaN
# 13661     NaN
# 13695     6-9
# 13719     6-7
# 13762     7-0
# Name: height, dtype: object>

# %%
nba_1998noncollege = nba_1998champion.loc[nba_champion["Year"] == 1998.0]
nba_1998noncollege = nba_1998champion.loc[nba_1998champion["Tm"] != "CHI"]
nba_1998noncollege = nba_1998champion["height"].mean                                      
nba_1998noncollege
# Out:
# <bound method Series.mean of 13855     6-6
# 13870     6-2
# 13874     6-6
# 13876     6-7
# 13880     6-8
# 14006     6-6
# 14054     NaN
# 14061     6-3
# 14065    6-11
# 14068    6-10
# 14072     6-2
# 14082     7-2
# 14170     NaN
# 14206     NaN
# 14241     6-9
# 14316    6-11
# 14317     6-9
# 14339     7-0
# Name: height, dtype: object>

# %%
nba_1999noncollege = nba_1999champion.loc[nba_champion["Year"] == 1999.0]
nba_1999noncollege = nba_1999champion.loc[nba_1999champion["Tm"] != "SAS"]
nba_1990noncollege = nba_1999champion["height"].mean                                      
nba_1990noncollege
# Out:
# <bound method Series.mean of 14487     6-4
# 14513    6-11
# 14516     6-5
# 14517     6-8
# 14544     6-7
# 14598     6-4
# 14606    5-10
# 14627     6-3
# 14628     6-7
# 14631     6-9
# 14737     7-0
# 14776     NaN
# 14787     6-7
# 14875     6-6
# Name: height, dtype: object>

# %%
nba_2000noncollege = nba_2000champion.loc[nba_champion["Year"] == 2000.0]
nba_2000noncollege = nba_2000champion.loc[nba_2000champion["Tm"] != "LAL"]
nba_2000noncollege = nba_2000champion["height"].mean                                      
nba_2000noncollege
# Out:
# <bound method Series.mean of 14967     6-6
# 14988     6-4
# 15054     6-1
# 15058     6-7
# 15071     6-8
# 15079     6-9
# 15089     6-6
# 15109     6-9
# 15126     6-4
# 15162     7-0
# 15182     6-0
# 15242     NaN
# 15289     6-7
# 15290     6-6
# 15310    6-11
# 15314     6-6
# Name: height, dtype: object>

# %%
nba_2001noncollege = nba_2001champion.loc[nba_champion["Year"] == 2001.0]
nba_2001noncollege = nba_2001champion.loc[nba_2001champion["Tm"] != "LAL"]
nba_2001noncollege = nba_2001champion["height"].mean                                      
nba_2001noncollege
# Out:
# <bound method Series.mean of 15468     6-6
# 15560     6-1
# 15563    6-11
# 15565     6-7
# 15579     6-8
# 15587    6-10
# 15599     6-6
# 15618     6-9
# 15687     6-0
# 15691     6-9
# 15726    6-10
# 15773     NaN
# 15799     6-3
# 15831     6-5
# 15858     6-6
# Name: height, dtype: object>

# %%
nba_2002noncollege = nba_2002champion.loc[nba_champion["Year"] == 2002.0]
nba_2002noncollege = nba_2002champion.loc[nba_2002champion["Tm"] != "LAL"]
nba_2002noncollege = nba_2002champion["height"].mean                                      
nba_2002noncollege
# Out:
# <bound method Series.mean of 16025     6-6
# 16057     6-0
# 16099     6-1
# 16109     6-7
# 16121     6-8
# 16161     6-9
# 16169     6-2
# 16230     6-9
# 16250    6-10
# 16256    6-10
# 16293     NaN
# 16318     6-3
# 16349     NaN
# 16374     6-6
# 16430     6-9
# Name: height, dtype: object>

# %%
nba_2003noncollege = nba_2003champion.loc[nba_champion["Year"] == 2003.0]
nba_2003noncollege = nba_2003champion.loc[nba_2003champion["Tm"] != "SAS"]
nba_2003noncollege = nba_2003champion["height"].mean                                      
nba_2003noncollege
# Out:
# <bound method Series.mean of 16489    6-11
# 16507     6-7
# 16518     6-5
# 16550    5-11
# 16585    6-11
# 16593    6-10
# 16613     6-6
# 16619     6-1
# 16679     6-8
# 16702     6-3
# 16802     6-2
# 16836     NaN
# 16843     6-7
# 16869     6-7
# 16945     7-0
# Name: height, dtype: object>

# %%
nba_2004noncollege = nba_2004champion.loc[nba_champion["Year"] == 2004.0]
nba_2004noncollege = nba_2004champion.loc[nba_2004champion["Tm"] != "DET"]
nba_2004noncollege = nba_2004champion["height"].mean                                      
nba_2004noncollege
# Out:
# <bound method Series.mean of 16974    5-11
# 17001     6-3
# 17048    6-11
# 17088     6-5
# 17130     6-8
# 17165     6-7
# 17166     6-6
# 17200     6-2
# 17216     6-2
# 17217     6-1
# 17304     7-0
# 17345    6-11
# 17386     6-9
# 17396     7-0
# 17455     6-5
# 17490     6-9
# 17496    6-10
# 17536     6-7
# Name: height, dtype: object>

# %%
nba_2005noncollege = nba_2005champion.loc[nba_champion["Year"] == 2005.0]
nba_2005noncollege = nba_2005champion.loc[nba_2005champion["Tm"] != "SAS"]
nba_2005noncollege = nba_2005champion["height"].mean                                      
nba_2005noncollege
# Out:
# <bound method Series.mean of 17586     6-6
# 17610     6-7
# 17623     6-5
# 17704    6-11
# 17743     6-6
# 17745     6-5
# 17782     6-9
# 17834     6-8
# 17875    6-10
# 17881     6-9
# 17907    6-10
# 17930     7-0
# 17954     6-2
# 17993     6-7
# 17994     6-6
# 18000     6-7
# 18073     6-3
# 18116    5-10
# Name: height, dtype: object>

# %%
nba_2006noncollege = nba_2006champion.loc[nba_champion["Year"] == 2006.0]
nba_2006noncollege = nba_2006champion.loc[nba_2006champion["Tm"] != "MIA"]
nba_2006noncollege = nba_2006champion["height"].mean                                      
nba_2006noncollege
# Out:
# <bound method Series.mean of 18149     6-5
# 18150     6-6
# 18177     7-0
# 18280    6-11
# 18303     6-3
# 18357     6-8
# 18422     6-8
# 18488     NaN
# 18511     NaN
# 18535     NaN
# 18545     6-8
# 18588     6-9
# 18663     6-4
# 18665     6-8
# 18670     6-6
# 18697     6-1
# 18709     6-9
# Name: height, dtype: object>

# %%
nba_2007noncollege = nba_2007champion.loc[nba_champion["Year"] == 2007.0]
nba_2007noncollege = nba_2007champion.loc[nba_2007champion["Tm"] != "SAS"]
nba_2007noncollege = nba_2007champion["height"].mean                               
nba_2007noncollege
# Out:
# <bound method Series.mean of 18744     6-6
# 18763    6-10
# 18768     6-7
# 18787    6-10
# 18839    6-11
# 18848     7-0
# 18851    6-10
# 18858     6-7
# 18878     6-6
# 18922     6-9
# 19070    6-10
# 19085     6-2
# 19188     6-3
# 19190     6-1
# 19213     6-7
# 19221     6-8
# Name: height, dtype: object>

# %%
nba_2008noncollege = nba_2008champion.loc[nba_champion["Year"] == 2008.0]
nba_2008noncollege = nba_2008champion.loc[nba_2008champion["Tm"] != "BOS"]
nba_2008noncollege = nba_2008champion["height"].mean                                      
nba_2008noncollege
# Out:
# <bound method Series.mean of 19251     6-5
# 19252     6-4
# 19319    6-11
# 19337     6-3
# 19364     6-9
# 19422    6-11
# 19490     6-1
# 19677    6-10
# 19682     6-7
# 19684    6-11
# 19685     6-8
# 19686     6-8
# 19691     6-4
# 19712     6-1
# 19720     6-9
# Name: height, dtype: object>

# %%
nba_2009noncollege = nba_2009champion.loc[nba_champion["Year"] == 2009.0]
nba_2009noncollege = nba_2009champion.loc[nba_2009champion["Tm"] != "LAL"]
nba_2009noncollege = nba_2009champion["height"].mean                                      
nba_2009noncollege
# Out:
# <bound method Series.mean of 19876     6-8
# 19944     6-4
# 19945     6-6
# 19949     7-0
# 20030     6-2
# 20036     6-1
# 20050     7-0
# 20119     7-0
# 20216     7-0
# 20238     6-8
# 20266    6-10
# 20286     6-9
# 20293    6-10
# 20398     6-7
# 20405     6-8
# 20444     6-9
# Name: height, dtype: object>

# %%
nba_2010noncollege = nba_2010champion.loc[nba_champion["Year"] == 2010.0]
nba_2010noncollege = nba_2010champion.loc[nba_2010champion["Tm"] != "LAL"]
nba_2010noncollege = nba_2010champion["height"].mean                                      
nba_2010noncollege
# Out:
# <bound method Series.mean of 20529     6-4
# 20530     6-6
# 20536     7-0
# 20605     6-2
# 20612     6-1
# 20624     7-0
# 20714     7-0
# 20841     6-8
# 20863    6-10
# 20884     6-9
# 20985     6-7
# 20993     6-8
# 21023     NaN
# Name: height, dtype: object>

# %%
nba_2011noncollege = nba_2011champion.loc[nba_champion["Year"] == 2011.0]
nba_2011noncollege = nba_2011champion.loc[nba_2011champion["Tm"] != "DAL"]
nba_2011noncollege = nba_2011champion["height"].mean                                      
nba_2011noncollege
# Out:
# <bound method Series.mean of 21035     7-2
# 21074     6-0
# 21091     6-0
# 21119     6-9
# 21132     6-7
# 21141     6-8
# 21157     7-1
# 21310     7-0
# 21375     6-4
# 21381     6-4
# 21414    6-11
# 21415     6-7
# 21464    6-10
# 21466     7-0
# 21483     6-8
# 21559     6-5
# 21563     6-9
# 21577     6-2
# Name: height, dtype: object>

# %%
nba_2012noncollege = nba_2012champion.loc[nba_champion["Year"] == 2012.0]
nba_2012noncollege = nba_2012champion.loc[nba_2012champion["Tm"] != "MIA"]
nba_2012noncollege = nba_2012champion["height"].mean                                      
nba_2012noncollege
# Out:
# <bound method Series.mean of 21682     6-9
# 21701     6-8
# 21722    6-11
# 21755     6-2
# 21760     6-2
# 21773     7-0
# 21857    6-11
# 21883     6-5
# 21885     6-8
# 21918     6-9
# 21935     6-8
# 21967     6-8
# 22027     6-8
# 22072    6-11
# 22157    6-10
# 22174     6-4
# Name: height, dtype: object>

# %%
nba_2013noncollege = nba_2013champion.loc[nba_champion["Year"] == 2013.0]
nba_2013noncollege = nba_2013champion.loc[nba_2013champion["Tm"] != "MIA"]
nba_2013noncollege = nba_2013champion["height"].mean
nba_2013noncollege
# Out:
# <bound method Series.mean of 22237     6-5
# 22244    6-10
# 22251     6-9
# 22271     6-8
# 22293    6-11
# 22320     6-2
# 22326     6-2
# 22438    6-10
# 22442     6-5
# 22447     6-8
# 22472     6-9
# 22484     6-8
# 22513     6-8
# 22548    6-10
# 22595     6-8
# 22651    6-11
# 22764     6-9
# 22769     6-4
# Name: height, dtype: object>

# %%
nba_2014noncollege = nba_2014champion.fillna(0)
nba_2014noncollege = nba_2014champion.loc[nba_champion["Year"] == 2014.0]
nba_2014noncollege = nba_2014champion.loc[nba_2014champion["Tm"] != "SAS"]
nba_2014noncollege = nba_2014champion["height"].mean                                      
nba_2014noncollege
# Out:
# <bound method Series.mean of 22849     6-9
# 22864    6-10
# 22870     6-5
# 22885    6-10
# 22904     6-4
# 22972    6-11
# 22974     NaN
# 22985     6-8
# 22994    6-11
# 23034     6-6
# 23048     6-6
# 23108     6-7
# 23114     6-5
# 23136     6-3
# 23160     6-7
# 23207     6-0
# 23259     6-2
# 23338    6-11
# 23362     6-9
# Name: height, dtype: object>

# %%
nba_2015noncollege = nba_2015champion.fillna(0)
nba_2015noncollege = nba_2015champion.loc[nba_champion["Year"] == 2015.0]
nba_2015noncollege = nba_2015champion.loc[nba_2015champion["Tm"] != "GSW"]
nba_2015noncollege = nba_2015champion["height"].mean                                      
nba_2015noncollege
# Out:
# <bound method Series.mean of 23470     6-3
# 23473     6-8
# 23500     7-0
# 23571     6-3
# 23625    6-11
# 23666     6-7
# 23711     6-6
# 23720     6-6
# 23777     7-1
# 23788     6-7
# 23789     6-9
# 23797     6-7
# 23816     NaN
# 23961     6-6
# 24003    6-10
# 24031     6-7
# Name: height, dtype: object>

# %%
nba_2016noncollege = nba_2016champion.fillna(0)
nba_2016noncollege = nba_2016champion.loc[nba_champion["Year"] == 2016.0]
nba_2016noncollege = nba_2016champion.loc[nba_2016champion["Tm"] != "CLE"]
nba_2016noncollege = nba_2016champion["height"].mean                                      
nba_2016noncollege
# Out:
# <bound method Series.mean of 24216     6-4
# 24227     6-4
# 24271    6-11
# 24316     6-6
# 24367     6-3
# 24370     6-8
# 24373     6-7
# 24395     6-6
# 24396     6-8
# 24405    6-11
# 24441    6-10
# 24472     6-6
# 24498     7-1
# 24585     6-5
# 24596     6-6
# 24630     6-9
# 24645    6-10
# 24677     6-1
# Name: height, dtype: object>

# %%
nba_2017noncollege = nba_2017champion.loc[nba_champion["Year"] == 2017.0]
nba_2017noncollege = nba_2017champion.loc[nba_2017champion["Tm"] != "GSW"]
nba_2017noncollege = nba_2017champion["height"].mean                                      
nba_2017noncollege
# Out:
# <bound method Series.mean of 24726     6-7
# 24792     6-3
# 24812     6-3
# 24838     6-9
# 24897     6-7
# 24954     6-6
# 24983     7-0
# 25025     6-7
# 25027     6-9
# 25042     NaN
# 25043     6-7
# 25056     7-0
# 25118    6-11
# 25222     6-7
# 25242    6-10
# 25256     6-2
# 25258     6-9
# Name: height, dtype: object>

# %%
nba_2018noncollege = nba_2018champion.fillna(0)
nba_2018noncollege = nba_2018champion.loc[nba_champion["Year"] == 2018.0]
nba_2018noncollege = nba_2018champion.loc[nba_2018champion["Tm"] != "GSW"]
nba_2018noncollege = nba_2018champion["height"].mean                                      
nba_2018noncollege
# Out:
# <bound method Series.mean of Series([], Name: height, dtype: object)>

# %%
plt.close('all')

#Average height of most win 
nba_college_champions = ["CHI", "LAL", "SAS", "MIA", "GSW",]
nba_college_champions_ave_height = [6.2, 6.6, 6.11, 6.5, 6.3]
x_axis = np.arange(len(nba_college_champions_ave_height))

# Create a bar chart based upon the above data
plt.bar(x_axis, nba_college_champions_ave_height, color="b", align="center")
# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, nba_college_champions)

# Set the limits
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(nba_college_champions_ave_height)+0.4)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# (0, 7.0)

# %%
plt.close('all')

# Give the chart a title, x label, and y label
plt.title("Most championship average height")
plt.xlabel("Team")
plt.ylabel("Bars Per Height")

#save
plt.savefig("mostchampionship.png", box_inche="tight")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
plt.close('all')

#Average height of least win
nba_college_champions = ["DET", "HOU", "BOS", "DAL", "CLE"]
nba_college_champions_ave_height = [6.6, 5.11, 6.5, 7.2, 6.4]
x_axis = np.arange(len(nba_college_champions_ave_height))

plt.bar(x_axis, nba_college_champions_ave_height, color="b", align="center")
# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, nba_college_champions)

# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# (-0.75, 4.75)

# %%
plt.close('all')

# Give the chart a title, x label, and y label
plt.title("Least championship average height")
plt.xlabel("Team")
plt.ylabel("Bars Per Height")

# Save an image of the chart and print it to the screen
plt.savefig("leastchampionship.png", box_inche="tight")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
