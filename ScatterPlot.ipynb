# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
nba_csv = "Data/NBAKeyStats.csv"
nba_key = pd.read_csv(nba_csv)
nba_key.head()
# Out:
#    Year  Rank Status                     Team   Age     W     L    PW  PL  \
# 0  1990   1.0     PQ            Phoenix Suns*  26.7  54.0  28.0  58.0  24
# 1  1990   2.0     PQ      Los Angeles Lakers*  28.9  63.0  19.0  58.0  24
# 2  1990   3.0     CC  Portland Trail Blazers*  26.7  59.0  23.0  57.0  25
# 3  1990   4.0   NBAC         Detroit Pistons*  29.5  59.0  23.0  57.0  25
# 4  1990   5.0     PQ               Utah Jazz*  27.6  55.0  27.0  54.0  28
#
#     MOV  ...   3PAr    TS%   eFG%  TOV%  ORB%  FT/FGA  eFG%.1  TOV%.1  DRB%  \
# 0  7.10  ...  0.076  0.565  0.509  13.3  31.1   0.302   0.478    12.8  68.8
# 1  6.78  ...  0.120  0.562  0.512  13.2  32.8   0.271   0.479    12.8  68.5
# 2  6.32  ...  0.075  0.535  0.486  13.4  36.5   0.269   0.479    15.2  70.8
# 3  6.09  ...  0.078  0.537  0.490  13.4  34.2   0.245   0.461    13.7  70.3
# 4  4.79  ...  0.096  0.570  0.522  15.5  30.1   0.284   0.468    13.4  69.5
#
#    FT/FGA.1
# 0     0.209
# 1     0.219
# 2     0.265
# ...

# %%
nba_key_simple = nba_key[["Year", "Status", "Team", "SRS", "eFG%", "Pace", "3PAr", "FTr", "TS%", 
                          "ORB%", "DRB%", "eFG%.1"]]
nba_key_simple.head()
# Out:
#    Year Status                     Team   SRS   eFG%   Pace   3PAr    FTr  \
# 0  1990     PQ            Phoenix Suns*  7.09  0.509  100.7  0.076  0.380
# 1  1990     PQ      Los Angeles Lakers*  6.74  0.512   96.3  0.120  0.345
# 2  1990     CC  Portland Trail Blazers*  6.48  0.486  102.3  0.075  0.362
# 3  1990   NBAC         Detroit Pistons*  5.41  0.490   94.4  0.078  0.323
# 4  1990     PQ               Utah Jazz*  4.82  0.522   96.1  0.096  0.377
#
#      TS%  ORB%  DRB%  eFG%.1
# 0  0.565  31.1  68.8   0.478
# 1  0.562  32.8  68.5   0.479
# 2  0.535  36.5  70.8   0.479
# 3  0.537  34.2  70.3   0.461
# 4  0.570  30.1  69.5   0.468

# %%
import seaborn as sns

# %%
sns.pairplot(x_vars=["SRS"], y_vars=["eFG%"], data=nba_key_simple, hue="Status", height=5)
# Out:
# <img src="data:image/png;base64,..." width="589">

# %%
plt.title("SRS & eFG%")
# Out:
# Text(0.5, 1.0, 'SRS & eFG%')

# %%
plt.savefig("SRSvsEFGScatter.png", bbox_inches="tight")
plt.show()
